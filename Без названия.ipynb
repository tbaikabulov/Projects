# %%
import pandas as pd

# %%
df = pd.read_csv('chat_messages.csv')

# %%
df
# Out:
#                   group            name           username          id  \
# 0     Startup Community  Alex Kolomiets        alexplaning   211794354
# 1     Startup Community          Andrii       shaposhn1k_a   461374968
# 2     Startup Community            I Am  Truefalsedecision   554068022
# 3     Startup Community            Alex             zdreny    61016306
# 4     Startup Community            Макс          rayhatr3d  1676504766
# ...                 ...             ...                ...         ...
# 2995  Startup Community  Alex Kolomiets        alexplaning   211794354
# 2996  Startup Community   M1o_ ГpqaHдés                NaN   550251314
# 2997  Startup Community  Alex Kolomiets        alexplaning   211794354
# 2998  Startup Community  Alex Kolomiets        alexplaning   211794354
# 2999  Startup Community   M1o_ ГpqaHдés                NaN   550251314
#
#                                                 message  \
# 0                     Что за поток вопросов без интро?)
# ...

# %%
df = pd.read_csv('chat_users.csv')

# %%
df
# Out:
#                   group               name       username            id
# 0     Startup Community   Виталий Сероусов       serousov  4.418822e+07
# 1     Startup Community         Protectron  ProtectronBot  6.962674e+08
# 2     Startup Community      Рут Иштрякова     ishtrykova  1.975210e+09
# 3     Startup Community                 H7            NaN  2.019764e+09
# 4     Startup Community     Alex Kolomiets    alexplaning  2.117944e+08
# ...                 ...                ...            ...           ...
# 4839  Startup Community   Shawnda Lunsford      lunsford0  1.916326e+09
# 4840  Startup Community    Louis Rodriguez            NaN  1.921183e+09
# 4841  Startup Community               Mmhh            NaN  1.923898e+09
# 4842  Startup Community        Jacob Burke            NaN  1.924836e+09
# 4843  Startup Community  Raymond Robertson            NaN  1.927232e+09
#
# [4844 rows x 4 columns]
